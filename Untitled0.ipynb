# %% [markdown]
# <a href="https://colab.research.google.com/github/KrstinaPerovic/Vezba-Python-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
email = "tema123"
pravi_email = "tema123"
lozinka = "l2ozinka"
prava_lozinka = "lozinka"

if email == pravi_email and lozinka == prava_lozinka:
  print("Loggin In")
else:
  print("Greska!")
# Out:
# Greska!

# %%
ptica = "vbac"

if ptica == "orao":
  print("Orao je brza ptica.")
elif ptica == "vrabac":
  print("Vrabac")
else:
  print("aa")
# Out:
# aa

# %%
korisnik_je_uneo = 12
for i in range(1, korisnik_je_uneo):
  print(i, "Marko")
# Out:
# 1 Marko
# 2 Marko
# 3 Marko
# 4 Marko
# 5 Marko
# 6 Marko
# 7 Marko
# 8 Marko
# 9 Marko
# 10 Marko
# 11 Marko

# %%
for i in range(0, 10):
  if i == 5:
    continue
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
k = 0

while k < 10:
  k += 1
  if k == 5:
     continue
  print(k)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
x = 0
while x<10:
  print("Marko")
  print("x = " + str(x))
  x = x+1
# Out:
# Marko
# x = 0
# Marko
# x = 1
# Marko
# x = 2
# Marko
# x = 3
# Marko
# x = 4
# Marko
# x = 5
# Marko
# x = 6
# Marko
# x = 7
# Marko
# x = 8
# Marko
# x = 9

# %%
shopping_list = ["meat", "apple", "banana", "orange"]

# %%
print(shopping_list)
# Out:
# ['meat', 'apple', 'banana', 'orange']

# %%
for i in shopping_list:
  print(i)
# Out:
# meat
# apple
# banana
# orange

# %%
print(shopping_list)
# Out:
# ['meat', 'apple', 'banana', 'orange', 'mango']

# %%
shopping_list.count("apples")
# Out:
# 0

# %%
obrisani_element = shopping_list.pop()
print(obrisani_element)
print(shopping_list)
# Out:
# banana
# ['meat', 'apple']

# %%
shopping_list.append("banana")
shopping_list.append("orange")

# %%
print(shopping_list)
# Out:
# ['meat', 'apple', 'banana', 'banana', 'orange']

# %%
shopping_list.remove("banana")

# %%
print(shopping_list)
# Out:
# ['meat', 'apple', 'banana', 'orange']

# %%
obrisani_el = shopping_list.pop(0)
obrisani_el
# Out:
# 'meat'

# %%
print(shopping_list)
# Out:
# ['apple', 'banana', 'orange']

# %%
shopping_list[1]
# Out:
# 'banana'

# %%
shopping_list
# Out:
# ['apple', 'banana', 'orange']

# %%
shopping_list
# Out:
# ['apple', 'banana', 'orange', 'meat']

# %%
shopping_list.append("meat")

# %%
shopping_list[:]
# Out:
# ['apple', 'banana', 'orange', 'meat']

# %%
shopping_list[2:4]
# Out:
# ['orange', 'meat']

# %%
def greet(name):
  print("Hello " + str(name))

# %%
greet("Milena")
# Out:
# Hello Milena

# %%
greet(9)
# Out:
# Hello 9

# %%
def greet(name = "Unknown name"):
  print("Name " + str(name))

# %%
greet("Milena")
# Out:
# Name Milena

# %%
greet()
# Out:
# Name Unknown name

# %%
def stepen(x, a = 2):
  return x**a

# %%
b = stepen(2)

# %%
b + 10
# Out:
# 14

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.isnull()
# Out:
#      CustomerID  Gender    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False   False  False               False                   False
# 1         False   False  False               False                   False
# 2         False   False  False               False                   False
# 3         False   False  False               False                   False
# 4         False   False  False               False                   False
# ..          ...     ...    ...                 ...                     ...
# 195       False   False  False               False                   False
# 196       False   False  False               False                   False
# 197       False   False  False               False                   False
# 198       False   False  False               False                   False
# 199       False   False  False               False                   False
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.loc[1]
# Out:
# CustomerID                   2
# Gender                    Male
# Age                         21
# Annual Income (k$)          15
# Spending Score (1-100)      81
# Name: 1, dtype: object

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.iloc[1]
# Out:
# CustomerID                   2
# Gender                    Male
# Age                         21
# Annual Income (k$)          15
# Spending Score (1-100)      81
# Name: 1, dtype: object

# %%
df.loc[:10]
# Out:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male   19                  15                      39
# 1            2    Male   21                  15                      81
# 2            3  Female   20                  16                       6
# 3            4  Female   23                  16                      77
# 4            5  Female   31                  17                      40
# 5            6  Female   22                  17                      76
# 6            7  Female   35                  18                       6
# 7            8  Female   23                  18                      94
# 8            9    Male   64                  19                       3
# 9           10  Female   30                  19                      72
# 10          11    Male   67                  19                      14

# %%
df.iloc[:10]
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
df.iloc[100]
# Out:
# CustomerID                   101
# Gender                    Female
# Age                           23
# Annual Income (k$)            62
# Spending Score (1-100)        41
# Name: 100, dtype: object

# %%
df.loc[100]
# Out:
# CustomerID                   101
# Gender                    Female
# Age                           23
# Annual Income (k$)            62
# Spending Score (1-100)        41
# Name: 100, dtype: object

# %%
df['Annual Income (k$)']
# Out:
# 0       15
# 1       15
# 2       16
# 3       16
# 4       17
#       ...
# 195    120
# 196    126
# 197    126
# 198    137
# 199    137
# Name: Annual Income (k$), Length: 200, dtype: int64

# %%
sns.histplot(df['Annual Income (k$)'], kde = True)
plt.title("Distribucija godisnjih prihoda")
plt.xlabel("Godisnji prihodi u hiljadama dolara")
plt.ylabel("Frekvencija")
plt.show()

# %% [markdown]
# Ovaj histogram nam pomaze da razumemo kako se godisnji prihodi raspodeljuju medju kupcima.
# Na histogramu vidimo da se godisnji prihodi vecinom krecu od 50-75 hiljada dolara. Takodje, postoje nekoliko kupaca sa visokim prihodina koji se krecu oko 100-130 hiljada dolara, ali su oni redji.
# Linija na grafiku nam daje glatku aprokcimaciju distribucije i potvrdjuje da je vecina kupaca u sredisnjem segmentu po pitanju godisnjeg prihoda.

# %%
sns.histplot(df['Spending Score (1-100)'], kde = True)
plt.title("Distribucija rejtinga potrosnje")
plt.xlabel("Rejting potrosnje")
plt.ylabel("Frekvencija")
plt.show()

# %% [markdown]
# Na histogramu mozemo videti da se rejting potrosnje vecinom koncentrise oko srednjih vrednosti, narocito oko 50. Postoje kupci i sa veoma visokim i veoma niskim rejtinom potrosnje, ali oni su redji.
# Kao i na prethodnom dijagramu i ovde imamo KDE liniju koja nam daje glatku aprokcimaciju distribucije i pokazuje da vecina kupaca ima srednji rejting potrosnje.

# %%
sns.histplot(df['Age'], kde = True, bins = 10)
plt.title("Distribucija starosti")
plt.xlabel("Starost")
plt.ylabel("Frekvencija")
plt.show()

# %% [markdown]
# Na ovom histogramu vidimo kako se starost kupaca raspodeljuje. Ovim dobijama potpuniju sliku. Vidimo da je akcenat na mladjoj populaciji, posebno oko 30-35 godina.

# %%
data = {'ime': ['Ana', 'Marko', 'Jelena'], 'godine': [23, 35, 29]}
df1 = pd.DataFrame(data, index = ['1', '2', '3'])

# %%
df1
# Out:
#       ime  godine
# 1     Ana      23
# 2   Marko      35
# 3  Jelena      29

# %%
df1.loc['1', 'godine']
# Out:
# 23

# %%
df1.iloc[2,1]
# Out:
# 29

# %%
#kreiranje_starosnih_grupa
bins = [10, 20, 30, 40, 50, 60, 70, 80]
labels = ['10-19','20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
df['Age-group'] = pd.cut(df['Age'], bins = bins, labels = labels, right= False )

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#   Age-group
# 0     10-19
# 1     20-29
# 2     20-29
# 3     20-29
# 4     30-39

# %%
#prosecan_SpendingScore_po_starosnojGrupi
age_sprening_score = df.groupby('Age-group')['Spending Score (1-100)'].mean().reset_index()
# Out:
# <ipython-input-10-2d8cd8db1c57>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_sprening_score = df.groupby('Age-group')['Spending Score (1-100)'].mean().reset_index()

# %%
age_sprening_score
# Out:
#   Age-group  Spending Score (1-100)
# 0     10-19               46.500000
# 1     20-29               61.953488
# 2     30-39               61.098361
# 3     40-49               34.948718
# 4     50-59               34.720000
# 5     60-69               41.611111
# 6     70-79               55.500000

# %%
#Vizualizacija_podataka
sns.barplot(x = 'Age-group', y = 'Spending Score (1-100)', data = age_sprening_score)
plt.title("Prosecan Spending Score po starosnoj grupi")
plt.xlabel("Starosna grupa")
plt.ylabel("Prosecan Spending Score")
plt.show()

# %% [markdown]
# Iz grafika i podataka mozemo videti da najvisi Spending Score imaju starosne grupe "20-29" i "30-39", oba oko 61. Starosne grupe "40-49" i "50-59" imaju znatno nizi Spending Score, oko 35. Ovo moze biti korisno za marketinske timove koji ciljaju na mladju populaicju za promocije i ponude.
